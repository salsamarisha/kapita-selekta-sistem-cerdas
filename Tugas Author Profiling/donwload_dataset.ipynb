# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/'Team Drives'/NLP/dataset/
# !ls
# Out:
# /content/drive/Team Drives/NLP/dataset

# %%
# Get training data
# !wget 'https://www.uni-weimar.de/medien/webis/corpora/corpus-pan-labs-09-today/pan-16/pan16-data/pan16-author-profiling-training-dataset-2016-04-25.zip'
# !unzip 'pan16-author-profiling-training-dataset-2016-04-25.zip'
# !mv 'pan16-author-profiling-training-dataset-2016-04-25' 'train'
# !rm 'pan16-author-profiling-training-dataset-2016-04-25.zip'
# Out:
# --2018-11-10 04:41:20--  https://www.uni-weimar.de/medien/webis/corpora/corpus-pan-labs-09-today/pan-16/pan16-data/pan16-author-profiling-training-dataset-2016-04-25.zip
# Resolving www.uni-weimar.de (www.uni-weimar.de)... 141.54.1.34
# Connecting to www.uni-weimar.de (www.uni-weimar.de)|141.54.1.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5806386 (5.5M) [application/zip]
# Saving to: ‘pan16-author-profiling-training-dataset-2016-04-25.zip’
#
# pan16-author-profil 100%[===================>]   5.54M  1.81MB/s    in 3.1s
#
# 2018-11-10 04:41:25 (1.81 MB/s) - ‘pan16-author-profiling-training-dataset-2016-04-25.zip’ saved [5806386/5806386]
#
# Archive:  pan16-author-profiling-training-dataset-2016-04-25.zip
#    creating: pan16-author-profiling-training-dataset-2016-04-25/
#   inflating: pan16-author-profiling-training-dataset-2016-04-25/pan16-author-profiling-training-dataset-dutch-2016-04-25.zip
# ...

# %%
# Get test data
# !wget 'https://s3.amazonaws.com/autoritas.pan/pan16-author-profiling-test-dataset-2016-05-07.zip'
# !unzip 'pan16-author-profiling-test-dataset-2016-05-07.zip'
# !mv 'pan16-author-profiling-test-dataset-2016-05-07' 'test'
# !rm 'pan16-author-profiling-test-dataset-2016-05-07.zip'
# Out:
# --2018-11-10 04:41:42--  https://s3.amazonaws.com/autoritas.pan/pan16-author-profiling-test-dataset-2016-05-07.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.1.198
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.1.198|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2146423 (2.0M) [application/zip]
# Saving to: ‘pan16-author-profiling-test-dataset-2016-05-07.zip’
#
# pan16-author-profil 100%[===================>]   2.05M  1.54MB/s    in 1.3s
#
# 2018-11-10 04:41:44 (1.54 MB/s) - ‘pan16-author-profiling-test-dataset-2016-05-07.zip’ saved [2146423/2146423]
#
# Archive:  pan16-author-profiling-test-dataset-2016-05-07.zip
#   inflating: pan16-author-profiling-test-dataset-2016-05-07/nl/163.xml
#   inflating: pan16-author-profiling-test-dataset-2016-05-07/nl/162.xml
#   inflating: pan16-author-profiling-test-dataset-2016-05-07/nl/240.xml
#   inflating: pan16-author-profiling-test-dataset-2016-05-07/nl/341.xml
# ...

# %%
# !ls
# Out:
# /content/drive/Team Drives/NLP/dataset
# test  train

# %%
# !ls train/
# Out:
# pan16-author-profiling-training-dataset-dutch-2016-04-25.zip
# pan16-author-profiling-training-dataset-english-2016-04-25.zip
# pan16-author-profiling-training-dataset-spanish-2016-04-25.zip

# %%
# !ls test/
# Out:
# en  en.txt  es	es.txt	nl  nl.txt

# %%
# Unzip all train dataset
# %cd 'train'
# !unzip '*.zip'
# !find . -type f -name '*.zip' -delete
# Out:
# /content/drive/Team Drives/NLP/dataset/train
# Archive:  pan16-author-profiling-training-dataset-dutch-2016-04-25.zip
#    creating: pan16-author-profiling-training-dataset-dutch-2016-04-25/
#   inflating: pan16-author-profiling-training-dataset-dutch-2016-04-25/100054075.xml
#   inflating: pan16-author-profiling-training-dataset-dutch-2016-04-25/10093352.xml
#   inflating: pan16-author-profiling-training-dataset-dutch-2016-04-25/101075388.xml
#   inflating: pan16-author-profiling-training-dataset-dutch-2016-04-25/103042619.xml
#   inflating: pan16-author-profiling-training-dataset-dutch-2016-04-25/103870086.xml
#   inflating: pan16-author-profiling-training-dataset-dutch-2016-04-25/104521127.xml
#   inflating: pan16-author-profiling-training-dataset-dutch-2016-04-25/104969269.xml
#   inflating: pan16-author-profiling-training-dataset-dutch-2016-04-25/105082350.xml
#   inflating: pan16-author-profiling-training-dataset-dutch-2016-04-25/1052624228.xml
# ...

# %%
# !ls
# Out:
# pan16-author-profiling-training-dataset-dutch-2016-04-25
# pan16-author-profiling-training-dataset-english-2016-04-25
# pan16-author-profiling-training-dataset-spanish-2016-04-25

# %%
# !mv 'pan16-author-profiling-training-dataset-dutch-2016-04-25' 'nl'
# !mv 'pan16-author-profiling-training-dataset-english-2016-04-25' 'en'
# !mv 'pan16-author-profiling-training-dataset-spanish-2016-04-25' 'es'

# %%
# !ls
# Out:
# sample_data
